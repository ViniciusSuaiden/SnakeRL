# %%
# !pip3 install torch torchvision torchaudio

# %%
# !pip3 install stable-baselines3[extra] protobuf==3.20.*

# %%
# !sudo apt install tesseract-ocr -y

# %%
# !sudo apt-get install python3-tk python3-dev -y

# %%
# !pip install mss pyautogui pytesseract

# %%
from mss import mss
import pyautogui
import cv2
import numpy as np
from matplotlib import pyplot as plt
import time
from gymnasium import Env
from gymnasium.spaces import Box, Discrete

import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

# %%
game_location = {'top': 125, 'left': 50, 'width': 60, 'height': 50}
img = mss().grab(game_location)
img = cv2.resize(np.array(img)[:, :, :3], (0, 0), fx=8, fy=8)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thr = cv2.cvtColor(cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1], cv2.COLOR_BGR2RGB)
plt.imshow(cv2.cvtColor(thr, cv2.COLOR_BGR2RGB))
pytesseract.image_to_string(thr, config="--psm 10 -c page_separator=''")
# Out:
# '7”\n'

# %%
class WebGame(Env):
    def __init__(self):
        super().__init__()
        # Setup spaces
        self.observation_space = Box(low=0, high=255, shape=(1,100,100), dtype=np.uint8)
        self.action_space = Discrete(4)
        # Capture game frames
        self.cap = mss()
        self.game_location = {'top': 100, 'left': 0, 'width': 600, 'height': 600}
        self.done_location = {'top': 600, 'left': 635, 'width': 75, 'height': 50}
        self.score_location = {'top': 125, 'left': 50, 'width': 60, 'height': 50}

    def step(self, action):
        action_map = {
            0: 'up',
            1: 'down',
            2: 'left',
            3: 'right'
        }
        pyautogui.press(action_map[action])

        reward, done = 0.01, False
        observation = self.get_observation()
        if self.frame == 2:
            done, done_cap = self.get_done() 
            self.frame = 0
        else:
            self.frame += 1
            if self.frame == 2:
                score = self.get_score()
                if score != self.previous_score:
                    reward = 1
                    self.previous_score = score
        
        info = {}
#         if done:
#             reward = -0.1
#         if (self.previous_action == 0 and action == 3) or (self.previous_action == 3 and action == 0):
#             reward = 1
#         self.previous_action = action
        return observation, reward, done, False, info

    def reset(self, **kwargs):
        self.previous_score = "0\n" 
        time.sleep(0.5)
        pyautogui.click(x=600, y=600)
        time.sleep(0.5)
        pyautogui.press('up')
        self.frame = 2
#         self.previous_action = 0
        return self.get_observation(), {}

    def get_observation(self):
        raw = np.array(self.cap.grab(self.game_location))[:,:,:3].astype(np.uint8)
        gray = cv2.cvtColor(raw, cv2.COLOR_BGR2GRAY)
        resized = cv2.resize(gray, (100,100))
        channel = np.reshape(resized, (1,100,100))
        return channel

    def get_score(self):
        score_cap = np.array(self.cap.grab(self.score_location))[:, :, :3]
        img = cv2.resize(score_cap, (0, 0), fx=8, fy=8)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        thr = cv2.cvtColor(cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1], cv2.COLOR_BGR2RGB)
        score_string = pytesseract.image_to_string(thr, config="--psm 10 -c page_separator=''")
        score = score_string
        return score

    def get_done(self):
        done_cap = np.array(self.cap.grab(self.done_location))[:, :, :3]
        img = cv2.resize(done_cap, (0, 0), fx=8, fy=8)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        thr = cv2.cvtColor(cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1], cv2.COLOR_BGR2RGB)
        done = False
        res = pytesseract.image_to_string(thr)
        if 'play' in res.lower():
            done = True
        return done, done_cap

# %%
env = WebGame()

for episode in range(20):
    obs = env.reset()
    terminated = False
    total_reward = 0
#     obs, reward, terminated, truncated, info =  env.step(3)
#     obs, reward, terminated, truncated, info =  env.step(1)
    while not terminated:
        action = model.predict(obs[0].reshape((1, 100, 100)))
        # print(action)
        obs, reward, terminated, truncated, info =  env.step(int(action[0]))
        total_reward  += reward
        if reward != 0:
            print(terminated, env.get_score(), reward)
    print('Total Reward for episode {} is {}'.format(episode, total_reward))
# Out:
# Total Reward for episode 0 is 0
# Total Reward for episode 1 is 0
# Total Reward for episode 2 is 0
# Total Reward for episode 3 is 0
# Total Reward for episode 4 is 0
# Total Reward for episode 5 is 0
# Total Reward for episode 6 is 0
# Total Reward for episode 7 is 0
# Total Reward for episode 8 is 0
# Total Reward for episode 9 is 0
# Total Reward for episode 10 is 0
# Total Reward for episode 11 is 0
# Total Reward for episode 12 is 0
# Total Reward for episode 13 is 0
# Total Reward for episode 14 is 0
# Total Reward for episode 15 is 0
# Total Reward for episode 16 is 0
# Total Reward for episode 17 is 0
# Total Reward for episode 18 is 0
# Total Reward for episode 19 is 0

# %%
print("Observation Space:", env.observation_space)
print("Observation Shape:", obs[0].shape)
try:
    action = model.predict(obs[0].reshape((1, 100, 100)))
except ValueError as e:
    print("An error occurred:", e)

# %%
# Import os for file path management
import os 
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback
# Check Environment    
from stable_baselines3.common import env_checker

# %%
env_checker.check_env(env)

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/post37/post/post/post/post/post/post/post/post/post/post/post1_2/post2_2/post_2/post2_2/post_2/post_2/post_4' # post23/post/post/post/post/post/post_2/post1_2/post_2/post6/post/post/post/post/post/post'
LOG_DIR = './logs/post37'

# %%
callback = TrainAndLoggingCallback(check_freq=5000, save_path=CHECKPOINT_DIR)

# %%
from stable_baselines3 import PPO, DQN

# %%
env = WebGame()

# %%
plt.imshow(cv2.cvtColor(env.get_observation()[0], cv2.COLOR_BGR2RGB))

# %%
model = PPO.load('./train/post37/post/post/post/post/post/post/post/post/post/post/post1_2/post2_2/post_2/post2_2/post_2/post_2/best_model_20000.zip', env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.0003, n_steps=128, ent_coef=0.01, gamma=0.97)
# model = DQN('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, buffer_size=10000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=41000, callback=callback)
# Out:
# Logging to ./logs/post37/PPO_29
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40       |
# |    ep_rew_mean     | 0.667    |
# | time/              |          |
# |    fps             | 4        |
# |    iterations      | 1        |
# |    time_elapsed    | 28       |
# |    total_timesteps | 128      |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.1        |
# |    ep_rew_mean          | 0.75        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 2           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 256         |
# | train/                  |             |
# |    approx_kl            | 0.076384164 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.805      |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0565     |
# |    n_updates            | 17750       |
# |    policy_gradient_loss | -0.0381     |
# |    value_loss           | 0.0104      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.2        |
# |    ep_rew_mean          | 0.769       |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 3           |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 384         |
# | train/                  |             |
# |    approx_kl            | 0.049304478 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.786      |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0526     |
# |    n_updates            | 17760       |
# |    policy_gradient_loss | -0.0292     |
# |    value_loss           | 0.0116      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 29.1       |
# |    ep_rew_mean          | 0.882      |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 4          |
# |    time_elapsed         | 121        |
# |    total_timesteps      | 512        |
# | train/                  |            |
# |    approx_kl            | 0.10206227 |
# |    clip_fraction        | 0.344      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.703     |
# |    explained_variance   | 0.831      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0928    |
# |    n_updates            | 17770      |
# |    policy_gradient_loss | -0.0636    |
# |    value_loss           | 0.0221     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.9        |
# |    ep_rew_mean          | 0.905       |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 5           |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 640         |
# | train/                  |             |
# |    approx_kl            | 0.046527762 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.663      |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0833     |
# |    n_updates            | 17780       |
# |    policy_gradient_loss | -0.0567     |
# |    value_loss           | 0.0481      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30.4       |
# |    ep_rew_mean          | 0.92       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 6          |
# |    time_elapsed         | 178        |
# |    total_timesteps      | 768        |
# | train/                  |            |
# |    approx_kl            | 0.06914673 |
# |    clip_fraction        | 0.277      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.741     |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0856    |
# |    n_updates            | 17790      |
# |    policy_gradient_loss | -0.0493    |
# |    value_loss           | 0.0056     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30.2       |
# |    ep_rew_mean          | 0.931      |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 7          |
# |    time_elapsed         | 207        |
# |    total_timesteps      | 896        |
# | train/                  |            |
# |    approx_kl            | 0.08392446 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.788     |
# |    explained_variance   | 0.972      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.07      |
# |    n_updates            | 17800      |
# |    policy_gradient_loss | -0.0456    |
# |    value_loss           | 0.00483    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 30.7      |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 4         |
# |    iterations           | 8         |
# |    time_elapsed         | 236       |
# |    total_timesteps      | 1024      |
# | train/                  |           |
# |    approx_kl            | 0.0709994 |
# |    clip_fraction        | 0.292     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.724    |
# |    explained_variance   | 0.989     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0869   |
# |    n_updates            | 17810     |
# |    policy_gradient_loss | -0.0529   |
# |    value_loss           | 0.00184   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.1        |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 9           |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 1152        |
# | train/                  |             |
# |    approx_kl            | 0.045286827 |
# |    clip_fraction        | 0.323       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 0.655       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0853     |
# |    n_updates            | 17820       |
# |    policy_gradient_loss | -0.057      |
# |    value_loss           | 0.0499      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.6        |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 10          |
# |    time_elapsed         | 297         |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.061973292 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.706      |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0685     |
# |    n_updates            | 17830       |
# |    policy_gradient_loss | -0.0609     |
# |    value_loss           | 0.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.5        |
# |    ep_rew_mean          | 1.04        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 11          |
# |    time_elapsed         | 326         |
# |    total_timesteps      | 1408        |
# | train/                  |             |
# |    approx_kl            | 0.019723162 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.68       |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0292     |
# |    n_updates            | 17840       |
# |    policy_gradient_loss | -0.0239     |
# |    value_loss           | 0.0186      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.6        |
# |    ep_rew_mean          | 1.04        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 12          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.043444984 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.759      |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0488     |
# |    n_updates            | 17850       |
# |    policy_gradient_loss | -0.0357     |
# |    value_loss           | 0.0118      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 29.6       |
# |    ep_rew_mean          | 1.04       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 13         |
# |    time_elapsed         | 386        |
# |    total_timesteps      | 1664       |
# | train/                  |            |
# |    approx_kl            | 0.09557151 |
# |    clip_fraction        | 0.337      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.651     |
# |    explained_variance   | 0.976      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0881    |
# |    n_updates            | 17860      |
# |    policy_gradient_loss | -0.0739    |
# |    value_loss           | 0.00413    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 29.4       |
# |    ep_rew_mean          | 1.03       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 14         |
# |    time_elapsed         | 415        |
# |    total_timesteps      | 1792       |
# | train/                  |            |
# |    approx_kl            | 0.11733945 |
# |    clip_fraction        | 0.292      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.573     |
# |    explained_variance   | 0.903      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0838    |
# |    n_updates            | 17870      |
# |    policy_gradient_loss | -0.0583    |
# |    value_loss           | 0.00733    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 29.5       |
# |    ep_rew_mean          | 1.05       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 15         |
# |    time_elapsed         | 447        |
# |    total_timesteps      | 1920       |
# | train/                  |            |
# |    approx_kl            | 0.08422971 |
# |    clip_fraction        | 0.227      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.546     |
# |    explained_variance   | 0.927      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0787    |
# |    n_updates            | 17880      |
# |    policy_gradient_loss | -0.0429    |
# |    value_loss           | 0.0126     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.4        |
# |    ep_rew_mean          | 1.03        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 16          |
# |    time_elapsed         | 476         |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.075615704 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.65       |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0995     |
# |    n_updates            | 17890       |
# |    policy_gradient_loss | -0.0691     |
# |    value_loss           | 0.0496      |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 29.3     |
# |    ep_rew_mean          | 1.03     |
# | time/                   |          |
# |    fps                  | 4        |
# |    iterations           | 17       |
# |    time_elapsed         | 507      |
# |    total_timesteps      | 2176     |
# | train/                  |          |
# |    approx_kl            | 0.070112 |
# |    clip_fraction        | 0.265    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.603   |
# |    explained_variance   | 0.938    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0506  |
# |    n_updates            | 17900    |
# |    policy_gradient_loss | -0.039   |
# |    value_loss           | 0.00858  |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 28.6      |
# |    ep_rew_mean          | 1.02      |
# | time/                   |           |
# |    fps                  | 4         |
# |    iterations           | 18        |
# |    time_elapsed         | 538       |
# |    total_timesteps      | 2304      |
# | train/                  |           |
# |    approx_kl            | 0.0662834 |
# |    clip_fraction        | 0.212     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.427    |
# |    explained_variance   | 0.969     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0502   |
# |    n_updates            | 17910     |
# |    policy_gradient_loss | -0.0351   |
# |    value_loss           | 0.00346   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.2        |
# |    ep_rew_mean          | 1.02        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 19          |
# |    time_elapsed         | 570         |
# |    total_timesteps      | 2432        |
# | train/                  |             |
# |    approx_kl            | 0.055284478 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.35       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0511     |
# |    n_updates            | 17920       |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 0.00173     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.3        |
# |    ep_rew_mean          | 1.01        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 20          |
# |    time_elapsed         | 599         |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.049798727 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0679     |
# |    n_updates            | 17930       |
# |    policy_gradient_loss | -0.0266     |
# |    value_loss           | 0.00178     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28.3       |
# |    ep_rew_mean          | 1.03       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 21         |
# |    time_elapsed         | 628        |
# |    total_timesteps      | 2688       |
# | train/                  |            |
# |    approx_kl            | 0.07288039 |
# |    clip_fraction        | 0.295      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.802     |
# |    explained_variance   | 0.945      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0566    |
# |    n_updates            | 17940      |
# |    policy_gradient_loss | -0.0438    |
# |    value_loss           | 0.00925    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.4        |
# |    ep_rew_mean          | 1.03        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 22          |
# |    time_elapsed         | 658         |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.050434034 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.672      |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0479     |
# |    n_updates            | 17950       |
# |    policy_gradient_loss | -0.0562     |
# |    value_loss           | 0.0854      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28.1       |
# |    ep_rew_mean          | 1.04       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 23         |
# |    time_elapsed         | 688        |
# |    total_timesteps      | 2944       |
# | train/                  |            |
# |    approx_kl            | 0.17049854 |
# |    clip_fraction        | 0.329      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.693     |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0702    |
# |    n_updates            | 17960      |
# |    policy_gradient_loss | -0.0449    |
# |    value_loss           | 0.00742    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28.7       |
# |    ep_rew_mean          | 1.06       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 24         |
# |    time_elapsed         | 717        |
# |    total_timesteps      | 3072       |
# | train/                  |            |
# |    approx_kl            | 0.06683484 |
# |    clip_fraction        | 0.316      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.718     |
# |    explained_variance   | 0.703      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.091     |
# |    n_updates            | 17970      |
# |    policy_gradient_loss | -0.0624    |
# |    value_loss           | 0.04       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28.6       |
# |    ep_rew_mean          | 1.05       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 25         |
# |    time_elapsed         | 746        |
# |    total_timesteps      | 3200       |
# | train/                  |            |
# |    approx_kl            | 0.04654043 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.832     |
# |    explained_variance   | 0.84       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0542    |
# |    n_updates            | 17980      |
# |    policy_gradient_loss | -0.0434    |
# |    value_loss           | 0.0221     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.8        |
# |    ep_rew_mean          | 1.06        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 26          |
# |    time_elapsed         | 775         |
# |    total_timesteps      | 3328        |
# | train/                  |             |
# |    approx_kl            | 0.061477948 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.733      |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0546     |
# |    n_updates            | 17990       |
# |    policy_gradient_loss | -0.0435     |
# |    value_loss           | 0.00831     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.7        |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 27          |
# |    time_elapsed         | 805         |
# |    total_timesteps      | 3456        |
# | train/                  |             |
# |    approx_kl            | 0.041689493 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.743      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0877     |
# |    n_updates            | 18000       |
# |    policy_gradient_loss | -0.05       |
# |    value_loss           | 0.00476     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.2        |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 28          |
# |    time_elapsed         | 835         |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.026872575 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.674      |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0299     |
# |    n_updates            | 18010       |
# |    policy_gradient_loss | -0.0252     |
# |    value_loss           | 0.00534     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28.2       |
# |    ep_rew_mean          | 1.04       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 29         |
# |    time_elapsed         | 865        |
# |    total_timesteps      | 3712       |
# | train/                  |            |
# |    approx_kl            | 0.06792737 |
# |    clip_fraction        | 0.305      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.671     |
# |    explained_variance   | 0.983      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0607    |
# |    n_updates            | 18020      |
# |    policy_gradient_loss | -0.0404    |
# |    value_loss           | 0.00311    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.9       |
# |    ep_rew_mean          | 1.02       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 30         |
# |    time_elapsed         | 895        |
# |    total_timesteps      | 3840       |
# | train/                  |            |
# |    approx_kl            | 0.07435316 |
# |    clip_fraction        | 0.302      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.725     |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0841    |
# |    n_updates            | 18030      |
# |    policy_gradient_loss | -0.0431    |
# |    value_loss           | 0.00858    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28          |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 31          |
# |    time_elapsed         | 925         |
# |    total_timesteps      | 3968        |
# | train/                  |             |
# |    approx_kl            | 0.034244224 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0709     |
# |    n_updates            | 18040       |
# |    policy_gradient_loss | -0.0255     |
# |    value_loss           | 0.00234     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28          |
# |    ep_rew_mean          | 1.01        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 32          |
# |    time_elapsed         | 954         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.045050934 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.652      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.101      |
# |    n_updates            | 18050       |
# |    policy_gradient_loss | -0.0523     |
# |    value_loss           | 0.00202     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28          |
# |    ep_rew_mean          | 1.01        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 33          |
# |    time_elapsed         | 984         |
# |    total_timesteps      | 4224        |
# | train/                  |             |
# |    approx_kl            | 0.040643543 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.733      |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0627     |
# |    n_updates            | 18060       |
# |    policy_gradient_loss | -0.0478     |
# |    value_loss           | 0.0474      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.1        |
# |    ep_rew_mean          | 1.01        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 34          |
# |    time_elapsed         | 1014        |
# |    total_timesteps      | 4352        |
# | train/                  |             |
# |    approx_kl            | 0.044610143 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.808      |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0836     |
# |    n_updates            | 18070       |
# |    policy_gradient_loss | -0.0603     |
# |    value_loss           | 0.00799     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.9       |
# |    ep_rew_mean          | 1.01       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 35         |
# |    time_elapsed         | 1045       |
# |    total_timesteps      | 4480       |
# | train/                  |            |
# |    approx_kl            | 0.03879743 |
# |    clip_fraction        | 0.243      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.718     |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.1       |
# |    n_updates            | 18080      |
# |    policy_gradient_loss | -0.0592    |
# |    value_loss           | 0.00448    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.8       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 36         |
# |    time_elapsed         | 1075       |
# |    total_timesteps      | 4608       |
# | train/                  |            |
# |    approx_kl            | 0.04204859 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.682     |
# |    explained_variance   | 0.77       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0697    |
# |    n_updates            | 18090      |
# |    policy_gradient_loss | -0.0431    |
# |    value_loss           | 0.028      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28         |
# |    ep_rew_mean          | 0.98       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 37         |
# |    time_elapsed         | 1104       |
# |    total_timesteps      | 4736       |
# | train/                  |            |
# |    approx_kl            | 0.09411827 |
# |    clip_fraction        | 0.273      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.719     |
# |    explained_variance   | 0.82       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0788    |
# |    n_updates            | 18100      |
# |    policy_gradient_loss | -0.0483    |
# |    value_loss           | 0.0211     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28.2       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 38         |
# |    time_elapsed         | 1133       |
# |    total_timesteps      | 4864       |
# | train/                  |            |
# |    approx_kl            | 0.05864548 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.758     |
# |    explained_variance   | 0.858      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0429    |
# |    n_updates            | 18110      |
# |    policy_gradient_loss | -0.0303    |
# |    value_loss           | 0.0165     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28.1       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 39         |
# |    time_elapsed         | 1163       |
# |    total_timesteps      | 4992       |
# | train/                  |            |
# |    approx_kl            | 0.10064386 |
# |    clip_fraction        | 0.304      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.689     |
# |    explained_variance   | 0.679      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0851    |
# |    n_updates            | 18120      |
# |    policy_gradient_loss | -0.0621    |
# |    value_loss           | 0.0524     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.5        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 40          |
# |    time_elapsed         | 1192        |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.085190035 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.48       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.08       |
# |    n_updates            | 18130       |
# |    policy_gradient_loss | -0.0491     |
# |    value_loss           | 0.0058      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.7        |
# |    ep_rew_mean          | 1.01        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 41          |
# |    time_elapsed         | 1223        |
# |    total_timesteps      | 5248        |
# | train/                  |             |
# |    approx_kl            | 0.106351286 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.574      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0863     |
# |    n_updates            | 18140       |
# |    policy_gradient_loss | -0.0512     |
# |    value_loss           | 0.00284     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.5        |
# |    ep_rew_mean          | 1.04        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 42          |
# |    time_elapsed         | 1255        |
# |    total_timesteps      | 5376        |
# | train/                  |             |
# |    approx_kl            | 0.036843635 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.49       |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.048      |
# |    n_updates            | 18150       |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 0.034       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.4        |
# |    ep_rew_mean          | 1.03        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 43          |
# |    time_elapsed         | 1285        |
# |    total_timesteps      | 5504        |
# | train/                  |             |
# |    approx_kl            | 0.047778547 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.386      |
# |    explained_variance   | 0.611       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.023      |
# |    n_updates            | 18160       |
# |    policy_gradient_loss | -0.0338     |
# |    value_loss           | 0.0729      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28.5       |
# |    ep_rew_mean          | 1.02       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 44         |
# |    time_elapsed         | 1314       |
# |    total_timesteps      | 5632       |
# | train/                  |            |
# |    approx_kl            | 0.05708113 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.505     |
# |    explained_variance   | 0.805      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0309    |
# |    n_updates            | 18170      |
# |    policy_gradient_loss | -0.0347    |
# |    value_loss           | 0.0414     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28.2       |
# |    ep_rew_mean          | 1.02       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 45         |
# |    time_elapsed         | 1344       |
# |    total_timesteps      | 5760       |
# | train/                  |            |
# |    approx_kl            | 0.08315867 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.607     |
# |    explained_variance   | 0.92       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.104     |
# |    n_updates            | 18180      |
# |    policy_gradient_loss | -0.0504    |
# |    value_loss           | 0.0155     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28         |
# |    ep_rew_mean          | 1.02       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 46         |
# |    time_elapsed         | 1375       |
# |    total_timesteps      | 5888       |
# | train/                  |            |
# |    approx_kl            | 0.08531068 |
# |    clip_fraction        | 0.351      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.63      |
# |    explained_variance   | 0.976      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.093     |
# |    n_updates            | 18190      |
# |    policy_gradient_loss | -0.0554    |
# |    value_loss           | 0.00328    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.9        |
# |    ep_rew_mean          | 1.02        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 47          |
# |    time_elapsed         | 1404        |
# |    total_timesteps      | 6016        |
# | train/                  |             |
# |    approx_kl            | 0.037756752 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0468     |
# |    n_updates            | 18200       |
# |    policy_gradient_loss | -0.0298     |
# |    value_loss           | 0.00863     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.7        |
# |    ep_rew_mean          | 1.03        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 48          |
# |    time_elapsed         | 1434        |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.042751618 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.645      |
# |    explained_variance   | 0.733       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0516     |
# |    n_updates            | 18210       |
# |    policy_gradient_loss | -0.0303     |
# |    value_loss           | 0.0461      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.6        |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 49          |
# |    time_elapsed         | 1464        |
# |    total_timesteps      | 6272        |
# | train/                  |             |
# |    approx_kl            | 0.045160443 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.545      |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0488     |
# |    n_updates            | 18220       |
# |    policy_gradient_loss | -0.0372     |
# |    value_loss           | 0.0341      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.6        |
# |    ep_rew_mean          | 1.07        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 50          |
# |    time_elapsed         | 1495        |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.030412419 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.445      |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0579     |
# |    n_updates            | 18230       |
# |    policy_gradient_loss | -0.0485     |
# |    value_loss           | 0.0513      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.3        |
# |    ep_rew_mean          | 1.07        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 51          |
# |    time_elapsed         | 1526        |
# |    total_timesteps      | 6528        |
# | train/                  |             |
# |    approx_kl            | 0.028380038 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.496      |
# |    explained_variance   | 0.828       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0457     |
# |    n_updates            | 18240       |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 0.0345      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.4       |
# |    ep_rew_mean          | 1.06       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 52         |
# |    time_elapsed         | 1555       |
# |    total_timesteps      | 6656       |
# | train/                  |            |
# |    approx_kl            | 0.05538582 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.432     |
# |    explained_variance   | 0.92       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0593    |
# |    n_updates            | 18250      |
# |    policy_gradient_loss | -0.0337    |
# |    value_loss           | 0.0127     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.3        |
# |    ep_rew_mean          | 1.06        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 53          |
# |    time_elapsed         | 1584        |
# |    total_timesteps      | 6784        |
# | train/                  |             |
# |    approx_kl            | 0.052369393 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.542      |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0412     |
# |    n_updates            | 18260       |
# |    policy_gradient_loss | -0.0297     |
# |    value_loss           | 0.00945     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.5        |
# |    ep_rew_mean          | 1.06        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 54          |
# |    time_elapsed         | 1613        |
# |    total_timesteps      | 6912        |
# | train/                  |             |
# |    approx_kl            | 0.057976075 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.624      |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0618     |
# |    n_updates            | 18270       |
# |    policy_gradient_loss | -0.0445     |
# |    value_loss           | 0.037       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.3       |
# |    ep_rew_mean          | 1.07       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 55         |
# |    time_elapsed         | 1645       |
# |    total_timesteps      | 7040       |
# | train/                  |            |
# |    approx_kl            | 0.07604974 |
# |    clip_fraction        | 0.318      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.642     |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.109     |
# |    n_updates            | 18280      |
# |    policy_gradient_loss | -0.0699    |
# |    value_loss           | 0.005      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.4       |
# |    ep_rew_mean          | 1.07       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 56         |
# |    time_elapsed         | 1676       |
# |    total_timesteps      | 7168       |
# | train/                  |            |
# |    approx_kl            | 0.04386881 |
# |    clip_fraction        | 0.269      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.674     |
# ...
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.815     |
# |    explained_variance   | 0.584      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.12      |
# |    n_updates            | 20760      |
# |    policy_gradient_loss | -0.0842    |
# |    value_loss           | 0.0449     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30.1       |
# |    ep_rew_mean          | 1.03       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 304        |
# |    time_elapsed         | 9063       |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.08906938 |
# |    clip_fraction        | 0.343      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.781     |
# |    explained_variance   | 0.927      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0733    |
# |    n_updates            | 20770      |
# |    policy_gradient_loss | -0.0517    |
# |    value_loss           | 0.0133     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30.4       |
# |    ep_rew_mean          | 1.04       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 305        |
# |    time_elapsed         | 9091       |
# |    total_timesteps      | 39040      |
# | train/                  |            |
# |    approx_kl            | 0.08454296 |
# |    clip_fraction        | 0.277      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.777     |
# |    explained_variance   | 0.891      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0853    |
# |    n_updates            | 20780      |
# |    policy_gradient_loss | -0.053     |
# |    value_loss           | 0.0159     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.6        |
# |    ep_rew_mean          | 1.08        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 306         |
# |    time_elapsed         | 9121        |
# |    total_timesteps      | 39168       |
# | train/                  |             |
# |    approx_kl            | 0.096605696 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.891      |
# |    explained_variance   | 0.377       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0796     |
# |    n_updates            | 20790       |
# |    policy_gradient_loss | -0.0514     |
# |    value_loss           | 0.118       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 30.5      |
# |    ep_rew_mean          | 1.08      |
# | time/                   |           |
# |    fps                  | 4         |
# |    iterations           | 307       |
# |    time_elapsed         | 9150      |
# |    total_timesteps      | 39296     |
# | train/                  |           |
# |    approx_kl            | 0.0560088 |
# |    clip_fraction        | 0.36      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.771    |
# |    explained_variance   | 0.657     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0941   |
# |    n_updates            | 20800     |
# |    policy_gradient_loss | -0.0753   |
# |    value_loss           | 0.0773    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30.5       |
# |    ep_rew_mean          | 1.09       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 308        |
# |    time_elapsed         | 9180       |
# |    total_timesteps      | 39424      |
# | train/                  |            |
# |    approx_kl            | 0.07726233 |
# |    clip_fraction        | 0.304      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.804     |
# |    explained_variance   | 0.909      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0876    |
# |    n_updates            | 20810      |
# |    policy_gradient_loss | -0.0706    |
# |    value_loss           | 0.0203     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30.8       |
# |    ep_rew_mean          | 1.1        |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 309        |
# |    time_elapsed         | 9209       |
# |    total_timesteps      | 39552      |
# | train/                  |            |
# |    approx_kl            | 0.10544349 |
# |    clip_fraction        | 0.377      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.722     |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.116     |
# |    n_updates            | 20820      |
# |    policy_gradient_loss | -0.0708    |
# |    value_loss           | 0.00686    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30.7       |
# |    ep_rew_mean          | 1.11       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 310        |
# |    time_elapsed         | 9240       |
# |    total_timesteps      | 39680      |
# | train/                  |            |
# |    approx_kl            | 0.06280152 |
# |    clip_fraction        | 0.344      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.815     |
# |    explained_variance   | 0.982      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.12      |
# |    n_updates            | 20830      |
# |    policy_gradient_loss | -0.0699    |
# |    value_loss           | 0.00278    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.6        |
# |    ep_rew_mean          | 1.08        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 311         |
# |    time_elapsed         | 9269        |
# |    total_timesteps      | 39808       |
# | train/                  |             |
# |    approx_kl            | 0.046591066 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.798      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.107      |
# |    n_updates            | 20840       |
# |    policy_gradient_loss | -0.0597     |
# |    value_loss           | 0.00285     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.2        |
# |    ep_rew_mean          | 1.1         |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 312         |
# |    time_elapsed         | 9298        |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.025710888 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.754      |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0647     |
# |    n_updates            | 20850       |
# |    policy_gradient_loss | -0.0318     |
# |    value_loss           | 0.00792     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 30.2      |
# |    ep_rew_mean          | 1.1       |
# | time/                   |           |
# |    fps                  | 4         |
# |    iterations           | 313       |
# |    time_elapsed         | 9327      |
# |    total_timesteps      | 40064     |
# | train/                  |           |
# |    approx_kl            | 0.1166814 |
# |    clip_fraction        | 0.291     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.629    |
# |    explained_variance   | 0.789     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0773   |
# |    n_updates            | 20860     |
# |    policy_gradient_loss | -0.0561   |
# |    value_loss           | 0.0382    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.7        |
# |    ep_rew_mean          | 1.09        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 314         |
# |    time_elapsed         | 9356        |
# |    total_timesteps      | 40192       |
# | train/                  |             |
# |    approx_kl            | 0.053951837 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0724     |
# |    n_updates            | 20870       |
# |    policy_gradient_loss | -0.0457     |
# |    value_loss           | 0.045       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.9        |
# |    ep_rew_mean          | 1.09        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 315         |
# |    time_elapsed         | 9386        |
# |    total_timesteps      | 40320       |
# | train/                  |             |
# |    approx_kl            | 0.069716975 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.724      |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0808     |
# |    n_updates            | 20880       |
# |    policy_gradient_loss | -0.0539     |
# |    value_loss           | 0.00545     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 31.2       |
# |    ep_rew_mean          | 1.1        |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 316        |
# |    time_elapsed         | 9415       |
# |    total_timesteps      | 40448      |
# | train/                  |            |
# |    approx_kl            | 0.07642633 |
# |    clip_fraction        | 0.309      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.71      |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.106     |
# |    n_updates            | 20890      |
# |    policy_gradient_loss | -0.0748    |
# |    value_loss           | 0.00556    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 31         |
# |    ep_rew_mean          | 1.07       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 317        |
# |    time_elapsed         | 9448       |
# |    total_timesteps      | 40576      |
# | train/                  |            |
# |    approx_kl            | 0.08879614 |
# |    clip_fraction        | 0.334      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.767     |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0978    |
# |    n_updates            | 20900      |
# |    policy_gradient_loss | -0.0625    |
# |    value_loss           | 0.00337    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.2        |
# |    ep_rew_mean          | 1.07        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 318         |
# |    time_elapsed         | 9479        |
# |    total_timesteps      | 40704       |
# | train/                  |             |
# |    approx_kl            | 0.044642564 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.619      |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0702     |
# |    n_updates            | 20910       |
# |    policy_gradient_loss | -0.0375     |
# |    value_loss           | 0.0302      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30.9       |
# |    ep_rew_mean          | 1.06       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 319        |
# |    time_elapsed         | 9509       |
# |    total_timesteps      | 40832      |
# | train/                  |            |
# |    approx_kl            | 0.06432016 |
# |    clip_fraction        | 0.317      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.732     |
# |    explained_variance   | 0.791      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0766    |
# |    n_updates            | 20920      |
# |    policy_gradient_loss | -0.0535    |
# |    value_loss           | 0.0298     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.4        |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 320         |
# |    time_elapsed         | 9538        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.062538944 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.791      |
# |    explained_variance   | 0.617       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0898     |
# |    n_updates            | 20930       |
# |    policy_gradient_loss | -0.0743     |
# |    value_loss           | 0.065       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 31.1       |
# |    ep_rew_mean          | 1.07       |
# | time/                   |            |
# |    fps                  | 4          |
# |    iterations           | 321        |
# |    time_elapsed         | 9565       |
# |    total_timesteps      | 41088      |
# | train/                  |            |
# |    approx_kl            | 0.06515807 |
# |    clip_fraction        | 0.276      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.732     |
# |    explained_variance   | 0.854      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0923    |
# |    n_updates            | 20940      |
# |    policy_gradient_loss | -0.0633    |
# |    value_loss           | 0.0167     |
# ----------------------------------------

# %%
# !tensorboard --logdir=logs/post37/PPO_29
# Out:
# TensorFlow installation not found - running with reduced feature set.
# /home/vini_suaiden/.local/lib/python3.9/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.33' not found (required by /home/vini_suaiden/.local/lib/python3.9/site-packages/tensorboard_data_server/bin/server)
# /home/vini_suaiden/.local/lib/python3.9/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.34' not found (required by /home/vini_suaiden/.local/lib/python3.9/site-packages/tensorboard_data_server/bin/server)
# /home/vini_suaiden/.local/lib/python3.9/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.32' not found (required by /home/vini_suaiden/.local/lib/python3.9/site-packages/tensorboard_data_server/bin/server)
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.14.0 at http://localhost:6006/ (Press CTRL+C to quit)

# %%
# !ls logs/post37
# Out:
# PPO_1	PPO_12	PPO_15	PPO_18	PPO_20	PPO_23	PPO_26	PPO_29	PPO_5  PPO_8
# PPO_10	PPO_13	PPO_16	PPO_19	PPO_21	PPO_24	PPO_27	PPO_3	PPO_6  PPO_9
# PPO_11	PPO_14	PPO_17	PPO_2	PPO_22	PPO_25	PPO_28	PPO_4	PPO_7

# %%
# !rm -r train/post31_2

# %%
# !ls /home/vini_suaiden/.local/lib/python3.9/site-packages
# Out:
# AutoROM
# AutoROM-0.6.1.dist-info
# AutoROM.accept_rom_license-0.6.1.dist-info
# AutoROM.py
# EasyProcess-1.1.dist-info
# Farama_Notifications-0.0.4.dist-info
# Markdown-3.4.4.dist-info
# MarkupSafe-2.0.1.dist-info
# MouseInfo-0.1.3.dist-info
# PIL
# Pillow-10.0.0.dist-info
# Pillow.libs
# PyAutoGUI-0.9.54.dist-info
# PyGetWindow-0.0.9.dist-info
# PyMsgBox-1.0.9.dist-info
# PyRect-0.2.0.dist-info
# PyScreeze-0.1.29.dist-info
# Pygments-2.16.1.dist-info
# Shimmy-1.1.0.dist-info
# Xlib
# __pycache__
# absl
# absl_py-1.4.0.dist-info
# ale_py
# ale_py-0.8.1.dist-info
# cachetools
# cachetools-5.3.1.dist-info
# click
# click-8.1.7.dist-info
# cloudpickle
# cloudpickle-2.2.1.dist-info
# cmake
# cmake-3.27.2.dist-info
# contourpy
# contourpy-1.1.0.dist-info
# cv2
# cycler-0.11.0.dist-info
# cycler.py
# dateutil
# easyprocess
# entrypoint2
# entrypoint2-1.1.dist-info
# farama_notifications
# filelock
# filelock-3.12.3.dist-info
# fontTools
# fonttools-4.42.1.dist-info
# functorch
# google
# google_auth-2.22.0.dist-info
# google_auth_oauthlib
# google_auth_oauthlib-1.0.0.dist-info
# grpc
# grpcio-1.57.0.dist-info
# gymnasium
# gymnasium-0.29.1.dist-info
# importlib_metadata
# importlib_metadata-6.8.0.dist-info
# importlib_resources
# importlib_resources-6.0.1.dist-info
# isympy.py
# jeepney
# jeepney-0.8.0.dist-info
# kiwisolver
# kiwisolver-1.4.5.dist-info
# lit
# lit-16.0.6.dist-info
# markdown
# markdown_it
# markdown_it_py-3.0.0.dist-info
# markupsafe
# matplotlib
# matplotlib-3.7.2-py3.9-nspkg.pth
# matplotlib-3.7.2.dist-info
# mdurl
# mdurl-0.1.2.dist-info
# mouseinfo
# mpl_toolkits
# mpmath
# mpmath-1.3.0.dist-info
# mss
# mss-9.0.1.dist-info
# networkx
# networkx-3.1.dist-info
# numpy
# numpy-1.25.2.dist-info
# numpy.libs
# nvfuser
# nvidia
# nvidia_cublas_cu11-11.10.3.66.dist-info
# nvidia_cuda_cupti_cu11-11.7.101.dist-info
# nvidia_cuda_nvrtc_cu11-11.7.99.dist-info
# nvidia_cuda_runtime_cu11-11.7.99.dist-info
# nvidia_cudnn_cu11-8.5.0.96.dist-info
# nvidia_cufft_cu11-10.9.0.58.dist-info
# nvidia_curand_cu11-10.2.10.91.dist-info
# nvidia_cusolver_cu11-11.4.0.1.dist-info
# nvidia_cusparse_cu11-11.7.4.91.dist-info
# nvidia_nccl_cu11-2.14.3.dist-info
# nvidia_nvtx_cu11-11.7.91.dist-info
# oauthlib
# oauthlib-3.2.2.dist-info
# opencv_python-4.8.0.76.dist-info
# opencv_python.libs
# packaging
# packaging-23.1.dist-info
# pandas
# pandas-2.1.0.dist-info
# protobuf-3.20.3-py3.9-nspkg.pth
# protobuf-3.20.3.dist-info
# pyasn1
# pyasn1-0.5.0.dist-info
# pyasn1_modules
# pyasn1_modules-0.3.0.dist-info
# pyautogui
# pygame
# pygame-2.5.1.dist-info
# pygame.libs
# pygetwindow
# pygments
# pylab.py
# pymsgbox
# pyperclip
# pyperclip-1.8.2.dist-info
# pyrect
# pyscreenshot
# pyscreenshot-3.1.dist-info
# pyscreeze
# pytesseract
# pytesseract-0.3.10.dist-info
# python3_xlib-0.15.dist-info
# python_dateutil-2.8.2.dist-info
# pytweening
# pytweening-1.0.7.dist-info
# pytz
# pytz-2023.3.dist-info
# requests_oauthlib
# requests_oauthlib-1.3.1.dist-info
# rich
# rich-13.5.2.dist-info
# rsa
# rsa-4.9.dist-info
# shimmy
# stable_baselines3
# stable_baselines3-2.1.0.dist-info
# sympy
# sympy-1.12.dist-info
# tensorboard
# tensorboard-2.14.0.dist-info
# tensorboard_data_server
# tensorboard_data_server-0.7.1.dist-info
# torch
# torch-2.0.1.dist-info
# torchaudio
# torchaudio-2.0.2.dist-info
# torchgen
# torchvision
# torchvision-0.15.2.dist-info
# torchvision.libs
# tqdm
# tqdm-4.66.1.dist-info
# triton
# triton-2.0.0.dist-info
# typing_extensions-4.7.1.dist-info
# typing_extensions.py
# tzdata
# tzdata-2023.3.dist-info
# werkzeug
# werkzeug-2.3.7.dist-info
# zipp
# zipp-3.16.2.dist-info

# %%
# !pip install pygad
# Out:
# Collecting pygad
#   Downloading pygad-3.2.0-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 4.2 MB/s eta 0:00:011
# Requirement already satisfied: numpy in /home/vini_suaiden/.local/lib/python3.9/site-packages (from pygad) (1.25.2)
# Requirement already satisfied: matplotlib in /home/vini_suaiden/.local/lib/python3.9/site-packages (from pygad) (3.7.2)
# Requirement already satisfied: cloudpickle in /home/vini_suaiden/.local/lib/python3.9/site-packages (from pygad) (2.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vini_suaiden/.local/lib/python3.9/site-packages (from matplotlib->pygad) (1.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/vini_suaiden/.local/lib/python3.9/site-packages (from matplotlib->pygad) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/vini_suaiden/.local/lib/python3.9/site-packages (from matplotlib->pygad) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/vini_suaiden/.local/lib/python3.9/site-packages (from matplotlib->pygad) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->pygad) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/vini_suaiden/.local/lib/python3.9/site-packages (from matplotlib->pygad) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vini_suaiden/.local/lib/python3.9/site-packages (from matplotlib->pygad) (4.42.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/vini_suaiden/.local/lib/python3.9/site-packages (from matplotlib->pygad) (6.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/vini_suaiden/.local/lib/python3.9/site-packages (from matplotlib->pygad) (23.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/vini_suaiden/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->pygad) (3.16.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->pygad) (1.16.0)
# Installing collected packages: pygad
# Successfully installed pygad-3.2.0

# %%
from torch import nn
import torch as th
import pygad

class NatureCNNAction(nn.Module):
    def __init__(self, observation_space, action_space, features_dim=512):
        super().__init__()

        n_input_channels = observation_space.shape[0]

        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=8, stride=4, padding=0),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=0),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.Flatten(),
        )

        with th.no_grad():
            n_flatten = self.cnn(th.as_tensor(observation_space.sample()[None]).float()).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())
        self.action_net = nn.Linear(features_dim, action_space.n)

    def forward(self, x):
        x = self.cnn(x)
        x = self.linear(x)
        return self.action_net(x)

# %%
net = NatureCNNAction(env.observation_space, env.action_space)

# %%
def encode_weights(net):
    return th.cat([p.flatten() for p in net.parameters()])

def decode_weights(vector, net):
    start = 0
    for p in net.parameters():
        end = start + p.numel()
        p.data.copy_(vector[start:end].view(p.size()))
        start = end

def fitness_func(ga_instance, solution, solution_idx):
    decode_weights(th.Tensor(solution), net)
    obs = env.reset()
    terminated = False
    total_reward = 0
    while not terminated:
        action = net(th.from_numpy(obs[0].reshape((1, 100, 100))).float())
        obs, reward, terminated, truncated, info =  env.step(int(action[0]))
        total_reward  += reward
    return total_reward

# %%
num_generations = 100
num_parents_mating = 5
keep_parents = 5
sol_per_pop = 50

initial_population = th.randn((sol_per_pop, encode_weights(net).shape[0])).numpy()

ga_instance = pygad.GA(
    num_generations=num_generations,
    num_parents_mating=num_parents_mating,
    fitness_func=fitness_func,
    sol_per_pop=sol_per_pop,
    num_genes=initial_population.shape[1],
    init_range_low=-1,
    init_range_high=1,
    parent_selection_type="rank",
    keep_parents=5,
    crossover_type=None,
    mutation_type="random",
    mutation_probability=1.0
)

# %%
ga_instance.run()
# Out:
# name 'torch' is not defined
# Traceback (most recent call last):
#   File "/home/vini_suaiden/.local/lib/python3.9/site-packages/pygad/pygad.py", line 1688, in cal_pop_fitness
#     fitness = self.fitness_func(self, sol, sol_idx)
#   File "<ipython-input-59-37cedc2e4756>", line 17, in fitness_func
#     action = net(torch.from_numpy(obs[0].reshape((1, 100, 100))).float())
# NameError: name 'torch' is not defined
# ERROR:pygad.pygad:name 'torch' is not defined
# Traceback (most recent call last):
#   File "/home/vini_suaiden/.local/lib/python3.9/site-packages/pygad/pygad.py", line 1688, in cal_pop_fitness
#     fitness = self.fitness_func(self, sol, sol_idx)
#   File "<ipython-input-59-37cedc2e4756>", line 17, in fitness_func
#     action = net(torch.from_numpy(obs[0].reshape((1, 100, 100))).float())
# NameError: name 'torch' is not defined
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/vini_suaiden/.local/lib/python3.9/site-packages/pygad/pygad.py", line 1688, in cal_pop_fitness
#     fitness = self.fitness_func(self, sol, sol_idx)
#   File "<ipython-input-59-37cedc2e4756>", line 17, in fitness_func
#     action = net(torch.from_numpy(obs[0].reshape((1, 100, 100))).float())
# NameError: name 'torch' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/IPython/core/interactiveshell.py", line 3427, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-61-e87ae048484f>", line 1, in <module>
#     ga_instance.run()
#   File "/home/vini_suaiden/.local/lib/python3.9/site-packages/pygad/pygad.py", line 1891, in run
#     self.last_generation_fitness = self.cal_pop_fitness()
#   File "/home/vini_suaiden/.local/lib/python3.9/site-packages/pygad/pygad.py", line 1848, in cal_pop_fitness
#     sys.exit(-1)
# SystemExit: -1
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/lib/python3/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/lib/python3/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.9/inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/.local/lib/python3.9/site-packages/pygad/pygad.py in cal_pop_fitness(self)
#    1687                         if self.fitness_batch_size in [1, None]:
# -> 1688                             fitness = self.fitness_func(self, sol, sol_idx)
#    1689                             if type(fitness) in GA.supported_int_float_types:
#
# <ipython-input-59-37cedc2e4756> in fitness_func(ga_instance, solution, solution_idx)
#      16     while not terminated:
# ---> 17         action = net(torch.from_numpy(obs[0].reshape((1, 100, 100))).float())
#      18         obs, reward, terminated, truncated, info =  env.step(int(action[0]))
#
# NameError: name 'torch' is not defined
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-61-e87ae048484f> in <module>
# ----> 1 ga_instance.run()
#
# ~/.local/lib/python3.9/site-packages/pygad/pygad.py in run(self)
#    1890             # Measuring the fitness of each chromosome in the population. Save the fitness in the last_generation_fitness attribute.
# -> 1891             self.last_generation_fitness = self.cal_pop_fitness()
#    1892
#
# ~/.local/lib/python3.9/site-packages/pygad/pygad.py in cal_pop_fitness(self)
#    1847             self.logger.exception(ex)
# -> 1848             sys.exit(-1)
#    1849         return pop_fitness
#
# SystemExit: -1
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                     stb = ['An exception has occurred, use %tb to see '
#    2046                            'the full traceback.\n']
# -> 2047                     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2048                                                                      value))
#    2049                 else:
#
# /usr/lib/python3/dist-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     752         value : exception value
#     753         """
# --> 754         return ListTB.structured_traceback(self, etype, value)
#     755
#     756     def show_exception_only(self, etype, evalue):
#
# /usr/lib/python3/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     627             chained_exceptions_tb_offset = 0
#     628             out_list = (
# --> 629                 self.structured_traceback(
#     630                     etype, evalue, (etb, chained_exc_ids),
#     631                     chained_exceptions_tb_offset, context)
#
# /usr/lib/python3/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# /usr/lib/python3/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# /usr/lib/python3/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# /usr/lib/python3/dist-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /usr/lib/python3/dist-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
obs = env.reset()

# %%
obs[0].reshape((1, 100, 100))
# Out:
# array([[[238, 238, 238, ..., 238, 238, 238],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [238, 238, 238, ..., 238, 238, 238],
#         [238, 238, 238, ..., 238, 238, 238],
#         [238, 238, 238, ..., 238, 238, 238]]], dtype=uint8)
